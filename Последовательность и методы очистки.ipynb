# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

# Нажмите Tab для автопредположений
planets = pd.read_csv('планеты.xls')
planets
# Out:
#     Planet       Mass Diameter  DayLength  SunDistance OrbitPeriod  \
# 0  MERCURY     0.3300     4879     4222.6         57.9          88
# 1    VENUS     4.8700   12,104     2802.0        108.2       224.7
# 2    EARTH     5.9700   12,756       24.0        149.6       365.2
# 3     MOON     0.0730     3475      708.7          NaN        27.3
# 4     MARS     0.6420     6792       24.7        227.9         687
# 5  JUPITER  1898.0000  142,984        9.9        778.6        4331
# 6   SATURN   568.0000  120,536       10.7       1433.5      10,747
# 7   URANUS    86.8000   51,118       17.2       2872.5      30,589
# 8  NEPTUNE   102.0000   49,528       16.1       4495.1      59,800
# 9    PLUTO     0.0146     2370      153.3       5906.4      90,560
#
#    OrbitVelocity  MeanTemperature  SurfacePressure  Moons Rings MagneticField  \
# 0           47.4              167          0.00000      0    No           Yes
# ...

# %%
planets = pd.read_csv('планеты.xls', usecols = [0, 1, 2, 3])
planets
# Out:
#     Planet       Mass Diameter  DayLength
# 0  MERCURY     0.3300     4879     4222.6
# 1    VENUS     4.8700   12,104     2802.0
# 2    EARTH     5.9700   12,756       24.0
# 3     MOON     0.0730     3475      708.7
# 4     MARS     0.6420     6792       24.7
# 5  JUPITER  1898.0000  142,984        9.9
# 6   SATURN   568.0000  120,536       10.7
# 7   URANUS    86.8000   51,118       17.2
# 8  NEPTUNE   102.0000   49,528       16.1
# 9    PLUTO     0.0146     2370      153.3

# %%
planets['Mass']
# Out:
# 0       0.3300
# 1       4.8700
# 2       5.9700
# 3       0.0730
# 4       0.6420
# 5    1898.0000
# 6     568.0000
# 7      86.8000
# 8     102.0000
# 9       0.0146
# Name: Mass, dtype: float64

# %%
# Точечное обращение тоже допустимо
planets.Mass
# Out:
# 0       0.3300
# 1       4.8700
# 2       5.9700
# 3       0.0730
# 4       0.6420
# 5    1898.0000
# 6     568.0000
# 7      86.8000
# 8     102.0000
# 9       0.0146
# Name: Mass, dtype: float64

# %%
planets.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
# Выбрать определенную строку
planets.loc[0]
# Out:
# Planet       MERCURY
# Mass            0.33
# Diameter        4879
# DayLength     4222.6
# Name: 0, dtype: object

# %%
planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Planet     10 non-null     object
#  1   Mass       10 non-null     float64
#  2   Diameter   10 non-null     object
#  3   DayLength  10 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 448.0+ bytes

# %%
len(planets)
# Out:
# 10

# %%
planets.loc[1]
# Out:
# Planet        VENUS
# Mass           4.87
# Diameter     12,104
# DayLength      2802
# Name: 1, dtype: object

# %%
# Ряд
planets.loc[1: 3]
# Out:
#   Planet   Mass Diameter  DayLength
# 1  VENUS  4.870   12,104     2802.0
# 2  EARTH  5.970   12,756       24.0
# 3   MOON  0.073     3475      708.7

# %%
planets.columns
# Out:
# Index(['Mass', 'Diameter', 'DayLength'], dtype='object')

# %%
planets = pd.read_csv('планеты.xls')
planets.FirstVisited[1]
# Out:
# '1962-08-27'

# %%
planets.loc[1].FirstVisited
# Out:
# '1962-08-27'

# %%
planets.loc[1: 3].FirstVisited
# Out:
# 1    1962-08-27
# 2           NaN
# 3    1959-09-12
# Name: FirstVisited, dtype: object

# %%
# Отобризим тип запрашиваемых данных
type(planets.loc[1: 3].FirstVisited)
# Out:
# pandas.core.series.Series

# %%
# Отобразим даты посещений
pd.to_datetime(planets.FirstVisited)
# Out:
# 0   1974-03-29
# 1   1962-08-27
# 2          NaT
# 3   1959-09-12
# 4   1965-07-15
# 5   1973-12-04
# 6   1979-09-01
# 7   1986-01-24
# 8   1989-08-25
# 9   2015-07-14
# Name: FirstVisited, dtype: datetime64[ns]

# %%
# Отобразим только год
planets.FirstVisited = pd.to_datetime(planets.FirstVisited)
planets.FirstVisited.dt.year
# Out:
# 0    1974.0
# 1    1962.0
# 2       NaN
# 3    1959.0
# 4    1965.0
# 5    1973.0
# 6    1979.0
# 7    1986.0
# 8    1989.0
# 9    2015.0
# Name: FirstVisited, dtype: float64
